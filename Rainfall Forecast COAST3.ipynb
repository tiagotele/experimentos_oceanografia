# %%
from BaseFunction import *
# Out:
# height has been deprecated.

# %% [markdown]
# # LOAD SST

# %%
sst_full_area_jul_dez_df = load_sst_data()

# %% [markdown]
# # LOAD PWS

# %%
pws_full_area_jul_dez_df = load_pws_data()

# %% [markdown]
# # Rainfall data

# %%
rainy_classified_df = build_rainfall_classified_df()

# %% [markdown]
# # Preprossessing(for coast3 area)

# %%
region_sst_df=pd.DataFrame(sst_full_area_jul_dez_df, index=sst_full_area_jul_dez_df.index, columns=colunas_coast_3)
region_pws_df=pd.DataFrame(pws_full_area_jul_dez_df, index=pws_full_area_jul_dez_df.index, columns=colunas_coast_3)

region_sst_df.dropna(axis=1, how='any', inplace=True)
region_pws_df.dropna(axis=1, how='any', inplace=True)

scaler = MinMaxScaler()

region_sst_scaled_df = pd.DataFrame(scaler.fit_transform(region_sst_df), columns=region_sst_df.columns)
region_sst_scaled_df.index = region_sst_df.index

replace_pws_scaled_df = pd.DataFrame(scaler.fit_transform(region_pws_df), columns=region_pws_df.columns)
replace_pws_scaled_df.index = region_pws_df.index

replace_sst_transformed_df = create_transformed_df(region_sst_scaled_df, "sst_")

replace_pws_transformed_df = create_transformed_df(replace_pws_scaled_df, "pws_")

df_new = pd.concat([replace_sst_transformed_df, replace_pws_transformed_df], axis=1)

dataset_df = pd.concat([df_new, rainy_classified_df], axis=1)
#Removing 2017 due we don't have full 2018 available
dataset_df = dataset_df.loc['1973-01-01':'2016-12-01']

# %%
region = "COAST3"

# %% [markdown]
# # Split train and test

# %%
n_classes = 3

# %%
train_df = dataset_df.loc['1973-01-01':'2000-12-01']

test_df = dataset_df.loc['2000-01-01':'2016-12-01']

#Dropt last column to be the X values
feature_cols = dataset_df.columns
feature_cols=feature_cols.drop('classes')

# Input data(X)
X_train = train_df.loc[:, feature_cols]

# Output data(y)
y_train = train_df['classes']

X_test = test_df.loc[:, feature_cols]

y_test = test_df['classes']

# %%
# Binarize the output
y_tr = label_binarize(y_train, classes=['weak', 'normal', 'strong'])
y_tt = label_binarize(y_test, classes=['weak', 'normal', 'strong'])

# %%
new_pred_class, classifier = test_knn(X_train,y_train, X_test)
# Out:
# 2001 weak
# 2002 weak
# 2003 weak
# 2004 normal
# 2005 weak
# 2006 weak
# 2007 normal
# 2008 weak
# 2009 weak
# 2010 weak
# 2011 weak
# 2012 weak
# 2013 weak
# 2014 weak
# 2015 weak
# 2016 weak

# %%
metrics.accuracy_score(test_df['classes'], new_pred_class)
# Out:
# 0.6875

# %%
plot_roc(classifier, X_train, X_test, y_tr, y_tt, n_classes, algorithm="KNN", area=region)
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/ranking.py:547: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
new_pred_class, classifier = test_svc(X_train,y_train, X_test)
# Out:
# 2001 weak
# 2002 weak
# 2003 weak
# 2004 weak
# 2005 weak
# 2006 weak
# 2007 weak
# 2008 weak
# 2009 weak
# 2010 weak
# 2011 weak
# 2012 weak
# 2013 weak
# 2014 weak
# 2015 weak
# 2016 weak

# %%
metrics.accuracy_score(test_df['classes'], new_pred_class)
# Out:
# 0.8125

# %%
plot_roc(classifier, X_train, X_test, y_tr, y_tt, n_classes, algorithm="Máquinas de Vetor de Suporte", area=region)
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/ranking.py:547: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
new_pred_class, classifier = test_gpc(X_train,y_train, X_test)
# Out:
# 2001 weak
# 2002 normal
# 2003 weak
# 2004 normal
# 2005 weak
# 2006 weak
# 2007 weak
# 2008 weak
# 2009 weak
# 2010 weak
# 2011 weak
# 2012 weak
# 2013 normal
# 2014 weak
# 2015 weak
# 2016 weak

# %%
metrics.accuracy_score(test_df['classes'], new_pred_class)
# Out:
# 0.625

# %%
plot_roc(classifier, X_train, X_test, y_tr, y_tt, n_classes, algorithm="Classificador Gaussiano", area=region)
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/ranking.py:547: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
new_pred_class, classifier = test_dtc(X_train,y_train, X_test)
# Out:
# 2001 weak
# 2002 normal
# 2003 normal
# 2004 normal
# 2005 strong
# 2006 strong
# 2007 strong
# 2008 normal
# 2009 strong
# 2010 strong
# 2011 strong
# 2012 normal
# 2013 normal
# 2014 normal
# 2015 normal
# 2016 normal

# %%
metrics.accuracy_score(test_df['classes'], new_pred_class)
# Out:
# 0.1875

# %%
plot_roc(classifier, X_train, X_test, y_tr, y_tt, n_classes, algorithm="Árvore de Decisão", area=region)
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/ranking.py:547: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
new_pred_class, classifier = test_rfc(X_train,y_train, X_test)
# Out:
# 2001 weak
# 2002 normal
# 2003 weak
# 2004 normal
# 2005 weak
# 2006 weak
# 2007 normal
# 2008 normal
# 2009 normal
# 2010 normal
# 2011 normal
# 2012 normal
# 2013 normal
# 2014 normal
# 2015 normal
# 2016 normal

# %%
metrics.accuracy_score(test_df['classes'], new_pred_class)
# Out:
# 0.3125

# %%
plot_roc(classifier, X_train, X_test, y_tr, y_tt, n_classes, algorithm="Floresta Aleatória", area=region)
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/ranking.py:547: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
new_pred_class, classifier = test_mlp(X_train,y_train, X_test)
# Out:
# 2001 normal
# 2002 normal
# 2003 normal
# 2004 normal
# 2005 normal
# 2006 normal
# 2007 normal
# 2008 normal
# 2009 normal
# 2010 normal
# 2011 normal
# 2012 normal
# 2013 normal
# 2014 normal
# 2015 normal
# 2016 normal

# %%
metrics.accuracy_score(test_df['classes'], new_pred_class)
# Out:
# 0.1875

# %%
plot_roc(classifier, X_train, X_test, y_tr, y_tt, n_classes, algorithm="Perceptron Multicamadas", area=region)
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/ranking.py:547: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
new_pred_class, classifier = test_adc(X_train,y_train, X_test)
# Out:
# 2001 weak
# 2002 normal
# 2003 normal
# 2004 normal
# 2005 weak
# 2006 weak
# 2007 weak
# 2008 normal
# 2009 weak
# 2010 weak
# 2011 weak
# 2012 normal
# 2013 normal
# 2014 normal
# 2015 normal
# 2016 normal

# %%
metrics.accuracy_score(test_df['classes'], new_pred_class)
# Out:
# 0.5

# %%
plot_roc(classifier, X_train, X_test, y_tr, y_tt, n_classes, algorithm="adc", area=region)
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/ranking.py:547: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
new_pred_class, classifier = test_gnb(X_train,y_train, X_test)
# Out:
# 2001 weak
# 2002 normal
# 2003 weak
# 2004 normal
# 2005 weak
# 2006 weak
# 2007 weak
# 2008 weak
# 2009 normal
# 2010 weak
# 2011 normal
# 2012 weak
# 2013 weak
# 2014 weak
# 2015 weak
# 2016 weak

# %%
metrics.accuracy_score(test_df['classes'], new_pred_class)
# Out:
# 0.6875

# %%
plot_roc(classifier, X_train, X_test, y_tr, y_tt, n_classes, algorithm="Naive Bayes Gaussiano", area=region)
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/ranking.py:547: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
